# %%
# %matplotlib inline

# %% [markdown]
# # Neural Style Transfer

# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
from resizeimage import resizeimage
import matplotlib.pyplot as plt

import torchvision.transforms as transforms
import torchvision.models as models

import copy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Loading the images

# %%
# desired size of the output image
imsize = 512 if torch.cuda.is_available() else 128  # use small size if no gpu

loader = transforms.Compose([
    transforms.Resize(imsize),  # scale imported image
    transforms.ToTensor()])  # transform it into a torch tensor
    
def image_loader(image_name):
    size = (300,300)
    image = Image.open(image_name)
#     image = resizeimage.resize_cover(image, TAILLE)
    resizer = transforms.Resize(size)
    image = resizer(image)
    # fake batch dimension required to fit network's input dimensions
    image = loader(image).unsqueeze(0)
    return image.to(device, torch.float)


# style_img = image_loader("./images/nympheas.jpg")
# content_img = image_loader("./images/mare.jpg")

# style_img = image_loader("./images/style.jpg")
# content_img = image_loader("./images/content.jpg")

# style_img = image_loader("./images/picasso.jpg")
# content_img = image_loader("./images/dancing.jpg")

style_img = image_loader("./images/nympheas.jpg")
content_img = image_loader("./images/kitty.jpg")

assert style_img.size() == content_img.size(), \
    "we need to import style and content images of the same size"

# %%
unloader = transforms.ToPILImage()  # reconvert into PIL image

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()  # we clone the tensor to not do changes on it
    image = image.squeeze(0)      # remove the fake batch dimension
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated


plt.figure()
imshow(style_img, title='Style Image')

plt.figure()
imshow(content_img, title='Content Image')

# %%
def showResult(content, style, result):
    fig = plt.figure(figsize=(16, 16))
    #fig, ax = plt.subplots(nrows=1, ncols=3)
    tensors = [content, result, style]
    titles = ['Content', 'Result', 'Style']
    
    for i in range(3):
        img = tensors[i].cpu().clone()
        img = img.squeeze(0)
        img = unloader(img)
        fig.add_subplot(1, 3, i+1)
        plt.imshow(img)
        plt.title(titles[i])
        plt.axis('off')
    
    plt.show()

# %% [markdown]
# ## Loss Functions
#
# ### Content Loss
#
# We will use the mean square error to compute the error between two sets of feature maps.

# %%
class ContentLoss(nn.Module):
   
    def __init__(self, target):
        super(ContentLoss, self).__init__()
        self.target = target.detach()
        
    def forward(self, input):
        self.loss = F.mse_loss(input, self.target)
        return input

# %% [markdown]
# ### Style Loss
#
# To compare the styles, we still use the mean square error, but we compare Gram matrix instead of feature map.

# %%
def gram_matrix(input):
    a, b, c, d = input.size()  # a=batch size(=1)
    # b=number of feature maps
    # (c,d)=dimensions of a f. map (N=c*d)

    features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL

    G = torch.mm(features, features.t())  # compute the gram product

    # we 'normalize' the values of the gram matrix
    # by dividing by the number of element in each feature maps.
    return G.div(a * b * c * d)

# %%
class StyleLoss(nn.Module):

    def __init__(self, target_feature):
        super(StyleLoss, self).__init__()
        self.target = gram_matrix(target_feature).detach()

    def forward(self, input):
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input

# %% [markdown]
# ## Importing the model
#
# We will use a pre-trained 19 layer VGG network as a model.

# %%
cnn = models.vgg19(pretrained=True).features.to(device).eval()

# %%
cnn_normalization_mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
cnn_normalization_std = torch.tensor([0.229, 0.224, 0.225]).to(device)

# create a module to normalize input image so we can easily put it in a
# nn.Sequential
class Normalization(nn.Module):
    def __init__(self, mean, std):
        super(Normalization, self).__init__()
        # .view the mean and std to make them [C x 1 x 1] so that they can
        # directly work with image Tensor of shape [B x C x H x W].
        # B is batch size. C is number of channels. H is height and W is width.
        self.mean = torch.tensor(mean).view(-1, 1, 1)
        self.std = torch.tensor(std).view(-1, 1, 1)

    def forward(self, img):
        # normalize img
        return (img - self.mean) / self.std

# %%
# desired depth layers to compute style/content losses :
content_layers_default = ['conv_22']
style_layers_default = ['conv_11', 'conv_12', 'conv_21', 'conv_22', 'conv_31']



def get_style_model_and_losses(cnn, normalization_mean, normalization_std,
                               style_img, content_img,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    cnn = copy.deepcopy(cnn)

    # normalization module
    normalization = Normalization(normalization_mean, normalization_std).to(device)

    # just in order to have an iterable access to or list of content/syle
    # losses
    content_losses = []
    style_losses = []

    # assuming that cnn is a nn.Sequential, so we make a new nn.Sequential
    # to put in modules that are supposed to be activated sequentially
    model = nn.Sequential(normalization)

    i = 10  # increment every time we see a conv
    j = 1   # increment every time we see a pool
    for layer in cnn.children():
        if isinstance(layer, nn.Conv2d):
            i += 1
            name = 'conv_{}'.format(i)
        elif isinstance(layer, nn.ReLU):
            name = 'relu_{}'.format(i)
            # The in-place version doesn't play very nicely with the ContentLoss
            # and StyleLoss we insert below. So we replace with out-of-place
            # ones here.
            layer = nn.ReLU(inplace=False)
        elif isinstance(layer, nn.MaxPool2d):
            name = 'pool_{}'.format(i)
            j += 1
            i = j * 10
        elif isinstance(layer, nn.BatchNorm2d):
            name = 'bn_{}'.format(i)
        else:
            raise RuntimeError('Unrecognized layer: {}'.format(layer.__class__.__name__))

        model.add_module(name, layer)
        #print(name)
        if name in content_layers:
            # add content loss:
            target = model(content_img).detach()
            content_loss = ContentLoss(target)
            model.add_module("content_loss_{}".format(i), content_loss)
            content_losses.append(content_loss)

        if name in style_layers:
            # add style loss:
            target_feature = model(style_img).detach()
            style_loss = StyleLoss(target_feature)
            model.add_module("style_loss_{}".format(i), style_loss)
            style_losses.append(style_loss)

    # now we trim off the layers after the last content and style losses
    for i in range(len(model) - 1, -1, -1):
        if isinstance(model[i], ContentLoss) or isinstance(model[i], StyleLoss):
            break

    model = model[:(i + 1)]

    return model, style_losses, content_losses

# %%
#input_img = torch.randn(content_img.data.size(), device=device) # white noise
input_img = content_img.clone() # content image

# add the original input image to the figure:
plt.figure()
imshow(input_img, title='Input Image')

# %% [markdown]
# ## Gradient descent
#
# We will use L-BFGS algorithm to run our gradient descent.

# %%
def get_input_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    optimizer = optim.LBFGS([input_img.requires_grad_()])
    return optimizer

# %%
def run_style_transfer(cnn, normalization_mean, normalization_std,
                       content_img, style_img, input_img, num_steps=300,
                       style_weight=1000000, content_weight=1):
    """Run the style transfer."""
    print('Building the style transfer model..')
    model, style_losses, content_losses = get_style_model_and_losses(cnn,
        normalization_mean, normalization_std, style_img, content_img)
    optimizer = get_input_optimizer(input_img)

    print('Optimizing..')
    run = [0]
    while run[0] <= num_steps:

        def closure():
            # correct the values of updated input image
            input_img.data.clamp_(0, 1)

            optimizer.zero_grad()
            model(input_img)
            style_score = 0
            content_score = 0

            for sl in style_losses:
                style_score += sl.loss
            for cl in content_losses:
                content_score += cl.loss

            style_score *= style_weight
            content_score *= content_weight

            loss = style_score + content_score
            loss.backward()

            run[0] += 1
            if run[0] % 50 == 0:
                print("run {}:".format(run))
                print('Style Loss : {:4f} Content Loss: {:4f}'.format(
                    style_score.item(), content_score.item()))
                print()

            return style_score + content_score

        optimizer.step(closure)

    # a last correction...
    input_img.data.clamp_(0, 1)

    return input_img

# %%
output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input_img)

# plt.figure()
# imshow(output, title='Output Image')
showResult(content_img, style_img, output)

# sphinx_gallery_thumbnail_number = 4
plt.ioff()
plt.show()

# %% [markdown]
# ## Experiments
#
# ### input influence

# %%
style_img = image_loader("./images/scream.jpg")
content_img = image_loader("./images/lena.png")

assert style_img.size() == content_img.size(), \
    "we need to import style and content images of the same size"

input1 = torch.randn(content_img.data.size(), device=device) # white noise
input2 = content_img.clone().detach() # content image

num_steps=400
style_weight=1000000
content_weight=1


output1 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input1, num_steps, style_weight, content_weight)

output2 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input2, num_steps, style_weight, content_weight)

print("white noise as input")
showResult(content_img, style_img, output1)
print("content as input")
showResult(content_img, style_img, output2)
# Out:
# Building the style transfer model..
# /home/felix/anaconda3/envs/AI/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if sys.path[0] == '':
# /home/felix/anaconda3/envs/AI/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   del sys.path[0]
# Optimizing..
# run [50]:
# Style Loss : 1934.591431 Content Loss: 197.435028
#
# run [100]:
# Style Loss : 750.031250 Content Loss: 192.377609
#
# run [150]:
# Style Loss : 492.203461 Content Loss: 190.210831
#
# run [200]:
# Style Loss : 374.658386 Content Loss: 188.718887
#
# run [250]:
# Style Loss : 302.686005 Content Loss: 186.862122
#
# run [300]:
# Style Loss : 258.384521 Content Loss: 185.018570
#
# run [350]:
# Style Loss : 229.076263 Content Loss: 183.184006
#
# run [400]:
# Style Loss : 207.817123 Content Loss: 182.193619
#
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 2047.631470 Content Loss: 145.099594
#
# run [100]:
# Style Loss : 768.137024 Content Loss: 159.321045
#
# run [150]:
# Style Loss : 458.023956 Content Loss: 161.281250
#
# run [200]:
# Style Loss : 352.189423 Content Loss: 162.031128
#
# run [250]:
# Style Loss : 294.182556 Content Loss: 161.918701
#
# run [300]:
# Style Loss : 258.201050 Content Loss: 161.591202
#
# run [350]:
# Style Loss : 232.635483 Content Loss: 161.378632
#
# run [400]:
# Style Loss : 214.210587 Content Loss: 161.106216
#
# white noise as input
# content as input

# %% [markdown]
# ### Content weight influence

# %%
style_img = image_loader("./images/starrynight.jpg")
content_img = image_loader("./images/placebourse.jpg")

assert style_img.size() == content_img.size(), \
    "we need to import style and content images of the same size"

input1 = content_img.clone().detach()
input2 = content_img.clone().detach()
input3 = content_img.clone().detach()


num_steps=400
style_weight=1000000
content_weight1=1
content_weight2=10
content_weight3=100


output1 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input1, num_steps, style_weight, content_weight1)

output2 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input2, num_steps, style_weight, content_weight2)

output3 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input3, num_steps, style_weight, content_weight3)

print("content weight =",content_weight1)
showResult(content_img, style_img, output1)
print("content weight =",content_weight2)
showResult(content_img, style_img, output2)
print("content weight =",content_weight3)
showResult(content_img, style_img, output3)
# Out:
# Building the style transfer model..
# /home/felix/anaconda3/envs/AI/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if sys.path[0] == '':
# /home/felix/anaconda3/envs/AI/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   del sys.path[0]
# Optimizing..
# run [50]:
# Style Loss : 143.889191 Content Loss: 27.877300
#
# run [100]:
# Style Loss : 37.501205 Content Loss: 26.693972
#
# run [150]:
# Style Loss : 19.807121 Content Loss: 24.672104
#
# run [200]:
# Style Loss : 12.790222 Content Loss: 22.935120
#
# run [250]:
# Style Loss : 10.014419 Content Loss: 21.395031
#
# run [300]:
# Style Loss : 8.408675 Content Loss: 20.370123
#
# run [350]:
# Style Loss : 7.226857 Content Loss: 19.571381
#
# run [400]:
# Style Loss : 6.325527 Content Loss: 19.010105
#
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 141.888947 Content Loss: 221.967453
#
# run [100]:
# Style Loss : 55.207436 Content Loss: 150.412109
#
# run [150]:
# Style Loss : 37.951241 Content Loss: 131.729965
#
# run [200]:
# Style Loss : 30.484093 Content Loss: 123.560715
#
# run [250]:
# Style Loss : 27.367125 Content Loss: 119.274658
#
# run [300]:
# Style Loss : 25.616274 Content Loss: 116.413643
#
# run [350]:
# Style Loss : 24.703495 Content Loss: 114.888603
#
# run [400]:
# Style Loss : 24.057030 Content Loss: 114.547119
#
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 351.804260 Content Loss: 956.396484
#
# run [100]:
# Style Loss : 208.409302 Content Loss: 759.808105
#
# run [150]:
# Style Loss : 188.169220 Content Loss: 741.352905
#
# run [200]:
# Style Loss : 192.143448 Content Loss: 751.693848
#
# run [250]:
# Style Loss : 19201.326172 Content Loss: 3146.874268
#
# run [300]:
# Style Loss : 15738928.000000 Content Loss: 38164.554688
#
# run [350]:
# Style Loss : 359.998016 Content Loss: 1312.574829
#
# run [400]:
# Style Loss : 211.061325 Content Loss: 900.611572
#
# content weight = 1
# content weight = 10
# content weight = 100

# %% [markdown]
# ### Style weight influence

# %%
style_img = image_loader("./images/compo7.jpg")
content_img = image_loader("./images/gt40.jpg")

assert style_img.size() == content_img.size(), \
    "we need to import style and content images of the same size"

input1 = content_img.clone().detach()
input2 = content_img.clone().detach()
input3 = content_img.clone().detach()


num_steps=400
style_weight1=1000000
style_weight2=100000
style_weight3=10000
content_weight=10


output1 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input1, num_steps, style_weight1, content_weight)

output2 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input2, num_steps, style_weight2, content_weight)

output3 = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input3, num_steps, style_weight3, content_weight)

print("style weight =",style_weight1)
showResult(content_img, style_img, output1)
print("style weight =",style_weight2)
showResult(content_img, style_img, output2)
print("style weight =",style_weight3)
showResult(content_img, style_img, output3)
# Out:
# Building the style transfer model..
# /home/felix/anaconda3/envs/AI/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if sys.path[0] == '':
# /home/felix/anaconda3/envs/AI/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   del sys.path[0]
# Optimizing..
# run [50]:
# Style Loss : 831.260437 Content Loss: 813.436340
#
# run [100]:
# Style Loss : 183.850327 Content Loss: 752.893433
#
# run [150]:
# Style Loss : 103.764763 Content Loss: 679.487244
#
# run [200]:
# Style Loss : 79.081062 Content Loss: 627.467590
#
# run [250]:
# Style Loss : 76.791969 Content Loss: 590.100952
#
# run [300]:
# Style Loss : 60.904945 Content Loss: 570.859497
#
# run [350]:
# Style Loss : 55.223888 Content Loss: 552.535950
#
# run [400]:
# Style Loss : 59.154747 Content Loss: 537.851807
#
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 102.875671 Content Loss: 587.119507
#
# run [100]:
# Style Loss : 54.857601 Content Loss: 471.924866
#
# run [150]:
# Style Loss : 49.941242 Content Loss: 429.844727
#
# run [200]:
# Style Loss : 195.877716 Content Loss: 400.548737
#
# run [250]:
# Style Loss : 49.477665 Content Loss: 409.290771
#
# run [300]:
# Style Loss : 70.464989 Content Loss: 443.928223
#
# run [350]:
# Style Loss : 89.172775 Content Loss: 449.152069
#
# run [400]:
# Style Loss : 54.561516 Content Loss: 446.163605
#
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 61.424206 Content Loss: 287.556366
#
# run [100]:
# Style Loss : 66.078232 Content Loss: 293.108490
#
# run [150]:
# Style Loss : 73.079384 Content Loss: 361.796326
#
# run [200]:
# Style Loss : 211.566742 Content Loss: 450.156311
#
# run [250]:
# Style Loss : 72.839600 Content Loss: 333.632019
#
# run [300]:
# Style Loss : 131.514664 Content Loss: 453.832703
#
# run [350]:
# Style Loss : 22844.572266 Content Loss: 1882.446533
#
# run [400]:
# Style Loss : 58469.968750 Content Loss: 2838.006348
#
# style weight = 1000000
# style weight = 100000
# style weight = 10000
